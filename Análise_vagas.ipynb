# %% [markdown]
# <a href="https://colab.research.google.com/github/antonioscript/SQL/blob/main/An%C3%A1lise_vagas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 - Importar e ler o pacote

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
vagas= pd.read_csv("/content/drive/MyDrive/01_Date/vagas.csv")
vagas
# Out:
#                                  Requisitos  Quantidade  Unnamed: 2  \
# 0                                       SQL          13         NaN
# 1                                REST APIs;          12         NaN
# 2                         Versionamento Git          10         NaN
# 3                            Flask e Django           7         NaN
# 4                                     NoSQL           7         NaN
# 5   Metodologias ágeis (Scrum e/ou Kanban);           6         NaN
# 6                                    Inglês           5         NaN
# 7                      Orientação a Objetos           4         NaN
# 8                        Biblioteca Request           2         NaN
# 9    Criação de interfaces gráficas (GUIs);           1         NaN
# 10   Leitura e escrita automatizada de PDFs           1         NaN
# 11                      Biblioteca Selenium           1         NaN
# 12               Scrapy / Extração de dados           1         NaN
#
# ...

# %% [markdown]
# #2 - Selecionar apenas as colunas que queremos

# %%
vagas.columns.values
# Out:
# array(['Requisitos', 'Quantidade', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8'], dtype=object)

# %%
colunas_selecionadas =['Requisitos', 'Quantidade']
new_vagas = vagas.filter(items=colunas_selecionadas) 
new_vagas
# Out:
#                                  Requisitos  Quantidade
# 0                                       SQL          13
# 1                                REST APIs;          12
# 2                         Versionamento Git          10
# 3                            Flask e Django           7
# 4                                     NoSQL           7
# 5   Metodologias ágeis (Scrum e/ou Kanban);           6
# 6                                    Inglês           5
# 7                      Orientação a Objetos           4
# 8                        Biblioteca Request           2
# 9    Criação de interfaces gráficas (GUIs);           1
# 10   Leitura e escrita automatizada de PDFs           1
# 11                      Biblioteca Selenium           1
# 12               Scrapy / Extração de dados           1

# %% [markdown]
# #3 - Plotando o Gráfico

# %%
new_vagas.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc46dc3da90>]],
#       dtype=object)
